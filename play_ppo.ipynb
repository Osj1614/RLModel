# %%
import gym
from rl.algo.ppo import PPO
import os
import torch as th
import time
import numpy as np
from gym.spaces import Box

from rl.module.actor_critic import ActorCriticNetwork2
from rl.module.general import DummyExtractor

from rl.vecenv import vecenv
import metaworld
from rl.metaenv_wrapper import MetaWrapper

import torch.utils.tensorboard

#, critic_coef=1, ent_coef=0.01, pred_coef=0.0, gamma=0.99, epsilon=0.2, lamda=0.95, policy_epochs=4

alg_args = {
    'name' : 'lunar',
    'nenvs' : 16,
    'nsteps' : 256,
    'gamma' : 0.99,
    'train_steps' : 1e6,
    'minibatches' : 256,
    'lr' : 3e-4,
}


def train(model, env, log_interval=0.01, save_interval=0.1):
    prevtime = time.time()
    saves = 1
    
    next_log = log_interval
    next_save = save_interval
    while next_log <= model.progress:
        next_log += log_interval
    while next_save <= model.progress:
        next_save += save_interval


    while os.path.isdir(f'logs/{model.name}/valid/{saves}'):
        saves += 1

    while model.progress < 1:
        model.train_epoch(env)
        if model.progress >= next_log:
            next_log += log_interval
            avg = np.mean(env.recent_scores)
            
            print(f"Average score:\t{round(avg,3)}")
            print(f"progress:\t{round(model.progress * 100, 2)}%")
            currtime = time.time()
            time_passed = currtime - prevtime
            print(f"elapsed time:\t{round(time_passed, 3)} second")
            print(f"time left:\t{round(time_passed*(1-model.progress)/log_interval/3600, 3)} hour")
            prevtime = currtime
            model.write_log('Average_score', avg)
            print('-----------------------------------------------------------')


if __name__ == '__main__':
    device = th.device('cuda' if th.cuda.is_available() else 'cpu')
    istrain = True
    
    env_name = 'LunarLander-v2'

    env = gym.make(env_name)

    extractor = DummyExtractor(env.observation_space.shape[0])


    if isinstance(env.action_space, Box):
        action_type = 'continuous'
        network = ActorCriticNetwork2(action_type, env.action_space.shape[0], extractor)
    else:
        action_type = 'discrete'
        network = ActorCriticNetwork2(action_type, env.action_space.n, extractor)

    

    envs = vecenv(alg_args['nenvs'], env_name, {})

    model = PPO(device, network, **alg_args)
    
    if istrain:
        train(model, envs, save_interval=1)
    else:
        #env = Monitor(env, f'./logs/{model.name}/video', force=True)
        state = env.reset()
        done = False
        while not done:
            action = model.model.get_action(th.as_tensor(state[None], dtype=th.float32).to(device))
            state, reward, done, info = env.step(action[0])

        env.close()
# Out:
# Average score:	-151.379
# progress:	1.23%
# elapsed time:	38.189 second
# time left:	1.048 hour
# -----------------------------------------------------------
# Average score:	-95.366
# progress:	2.05%
# elapsed time:	25.835 second
# time left:	0.703 hour
# -----------------------------------------------------------
# Average score:	-54.024
# progress:	3.28%
# elapsed time:	41.479 second
# time left:	1.114 hour
# -----------------------------------------------------------
# Average score:	-43.85
# progress:	4.1%
# elapsed time:	38.489 second
# time left:	1.025 hour
# -----------------------------------------------------------
# Average score:	-24.889
# progress:	5.32%
# elapsed time:	61.112 second
# time left:	1.607 hour
# -----------------------------------------------------------
# Average score:	-5.258
# progress:	6.14%
# elapsed time:	39.942 second
# time left:	1.041 hour
# -----------------------------------------------------------
# Average score:	15.252
# progress:	7.37%
# elapsed time:	66.086 second
# time left:	1.7 hour
# -----------------------------------------------------------
# Average score:	26.066
# progress:	8.19%
# elapsed time:	42.681 second
# time left:	1.088 hour
# -----------------------------------------------------------
# Average score:	40.346
# progress:	9.01%
# elapsed time:	40.251 second
# time left:	1.017 hour
# -----------------------------------------------------------
# Average score:	51.28
# progress:	10.24%
# elapsed time:	64.168 second
# time left:	1.6 hour
# -----------------------------------------------------------
# Average score:	63.136
# progress:	11.06%
# elapsed time:	39.426 second
# time left:	0.974 hour
# -----------------------------------------------------------
# Average score:	78.11
# progress:	12.29%
# elapsed time:	59.995 second
# time left:	1.462 hour
# -----------------------------------------------------------
# Average score:	83.097
# progress:	13.11%
# elapsed time:	39.736 second
# time left:	0.959 hour
# -----------------------------------------------------------
# Average score:	95.325
# progress:	14.34%
# elapsed time:	58.235 second
# time left:	1.386 hour
# -----------------------------------------------------------
# Average score:	102.712
# progress:	15.16%
# elapsed time:	36.368 second
# time left:	0.857 hour
# -----------------------------------------------------------
# Average score:	127.738
# progress:	16.38%
# elapsed time:	49.439 second
# time left:	1.148 hour
# -----------------------------------------------------------
# Average score:	135.19
# progress:	17.2%
# elapsed time:	30.814 second
# time left:	0.709 hour
# -----------------------------------------------------------
# Average score:	108.994
# progress:	18.02%
# elapsed time:	27.569 second
# time left:	0.628 hour
# -----------------------------------------------------------
# Average score:	135.359
# progress:	19.25%
# elapsed time:	44.226 second
# time left:	0.992 hour
# -----------------------------------------------------------
# Average score:	166.085
# progress:	20.07%
# elapsed time:	30.909 second
# time left:	0.686 hour
# -----------------------------------------------------------
# Average score:	175.775
# progress:	21.3%
# elapsed time:	44.502 second
# time left:	0.973 hour
# -----------------------------------------------------------
# Average score:	183.632
# progress:	22.12%
# elapsed time:	28.181 second
# time left:	0.61 hour
# -----------------------------------------------------------
# Average score:	201.866
# progress:	23.35%
# elapsed time:	42.759 second
# time left:	0.91 hour
# -----------------------------------------------------------
# Average score:	183.489
# progress:	24.17%
# elapsed time:	29.913 second
# time left:	0.63 hour
# -----------------------------------------------------------
# /home/depthfirst/RLModel/rl/algo/ppo.py:207: RuntimeWarning: divide by zero encountered in double_scalars
#   self.write_log('avg_score', self.reward_log / self.cnt_log)
# avg_score is NaN. -inf
# Average score:	181.153
# progress:	25.4%
# elapsed time:	52.657 second
# time left:	1.091 hour
# -----------------------------------------------------------
# Average score:	178.02
# progress:	26.21%
# elapsed time:	37.496 second
# time left:	0.769 hour
# -----------------------------------------------------------
# avg_score is NaN. -inf
# Average score:	174.946
# progress:	27.03%
# elapsed time:	40.733 second
# time left:	0.826 hour
# -----------------------------------------------------------
# avg_score is NaN. -inf
# Average score:	163.808
# progress:	28.26%
# elapsed time:	60.696 second
# time left:	1.21 hour
# -----------------------------------------------------------
# avg_score is NaN. inf
# Average score:	160.914
# progress:	29.08%
# elapsed time:	41.167 second
# time left:	0.811 hour
# -----------------------------------------------------------
# Average score:	158.297
# progress:	30.31%
# elapsed time:	55.822 second
# time left:	1.081 hour
# -----------------------------------------------------------
# Average score:	165.982
# progress:	31.13%
# elapsed time:	38.385 second
# time left:	0.734 hour
# -----------------------------------------------------------
# Average score:	180.487
# progress:	32.36%
# elapsed time:	49.241 second
# time left:	0.925 hour
# -----------------------------------------------------------
# Average score:	196.678
# progress:	33.18%
# elapsed time:	30.759 second
# time left:	0.571 hour
# -----------------------------------------------------------
# Average score:	92.972
# progress:	34.41%
# elapsed time:	43.501 second
# time left:	0.793 hour
# -----------------------------------------------------------
# Average score:	67.094
# progress:	35.23%
# elapsed time:	29.867 second
# time left:	0.537 hour
# -----------------------------------------------------------
# Average score:	110.456
# progress:	36.04%
# elapsed time:	29.37 second
# time left:	0.522 hour
# -----------------------------------------------------------
# Average score:	194.519
# progress:	37.27%
# elapsed time:	33.46 second
# time left:	0.583 hour
# -----------------------------------------------------------
# Average score:	209.294
# progress:	38.09%
# elapsed time:	30.102 second
# time left:	0.518 hour
# -----------------------------------------------------------
# avg_score is NaN. -inf
# Average score:	216.74
# progress:	39.32%
# elapsed time:	52.536 second
# time left:	0.886 hour
# -----------------------------------------------------------
# Average score:	212.781
# progress:	40.14%
# elapsed time:	33.746 second
# time left:	0.561 hour
# -----------------------------------------------------------
# avg_score is NaN. -inf
# Average score:	202.096
# progress:	41.37%
# elapsed time:	54.858 second
# time left:	0.893 hour
# -----------------------------------------------------------
# Average score:	191.919
# progress:	42.19%
# elapsed time:	37.729 second
# time left:	0.606 hour
# -----------------------------------------------------------
# Average score:	172.498
# progress:	43.01%
# elapsed time:	39.409 second
# time left:	0.624 hour
# -----------------------------------------------------------
# Average score:	155.004
# progress:	44.24%
# elapsed time:	62.204 second
# time left:	0.964 hour
# -----------------------------------------------------------
# Average score:	148.759
# progress:	45.06%
# elapsed time:	35.431 second
# time left:	0.541 hour
# -----------------------------------------------------------
# Average score:	164.994
# progress:	46.28%
# elapsed time:	48.6 second
# time left:	0.725 hour
# -----------------------------------------------------------
# Average score:	167.635
# progress:	47.1%
# elapsed time:	32.311 second
# time left:	0.475 hour
# -----------------------------------------------------------
# Average score:	164.864
# progress:	48.33%
# elapsed time:	51.89 second
# time left:	0.745 hour
# -----------------------------------------------------------
# Average score:	164.278
# progress:	49.15%
# elapsed time:	34.643 second
# time left:	0.489 hour
# -----------------------------------------------------------
# Average score:	142.14
# progress:	50.38%
# elapsed time:	53.805 second
# time left:	0.742 hour
# -----------------------------------------------------------
# Average score:	133.765
# progress:	51.2%
# elapsed time:	35.758 second
# time left:	0.485 hour
# -----------------------------------------------------------
# Average score:	121.845
# progress:	52.02%
# elapsed time:	33.917 second
# time left:	0.452 hour
# -----------------------------------------------------------
# Average score:	109.944
# progress:	53.25%
# elapsed time:	54.066 second
# time left:	0.702 hour
# -----------------------------------------------------------
# Average score:	128.071
# progress:	54.07%
# elapsed time:	33.252 second
# time left:	0.424 hour
# -----------------------------------------------------------
# Average score:	138.688
# progress:	55.3%
# elapsed time:	51.222 second
# time left:	0.636 hour
# -----------------------------------------------------------
# Average score:	162.317
# progress:	56.12%
# elapsed time:	32.973 second
# time left:	0.402 hour
# -----------------------------------------------------------
# Average score:	189.285
# progress:	57.34%
# elapsed time:	47.502 second
# time left:	0.563 hour
# -----------------------------------------------------------
# Average score:	138.625
# progress:	58.16%
# elapsed time:	26.857 second
# time left:	0.312 hour
# -----------------------------------------------------------
# Average score:	188.091
# progress:	59.39%
# elapsed time:	42.448 second
# time left:	0.479 hour
# -----------------------------------------------------------
# Average score:	224.975
# progress:	60.21%
# elapsed time:	30.803 second
# time left:	0.34 hour
# -----------------------------------------------------------
# Average score:	249.294
# progress:	61.03%
# elapsed time:	32.138 second
# time left:	0.348 hour
# -----------------------------------------------------------
# Average score:	246.592
# progress:	62.26%
# elapsed time:	47.762 second
# time left:	0.501 hour
# -----------------------------------------------------------
# Average score:	240.45
# progress:	63.08%
# elapsed time:	38.639 second
# time left:	0.396 hour
# -----------------------------------------------------------
# Average score:	228.627
# progress:	64.31%
# elapsed time:	43.453 second
# time left:	0.431 hour
# -----------------------------------------------------------
# Average score:	224.189
# progress:	65.13%
# elapsed time:	36.369 second
# time left:	0.352 hour
# -----------------------------------------------------------
# Average score:	206.477
# progress:	66.36%
# elapsed time:	57.459 second
# time left:	0.537 hour
# -----------------------------------------------------------
# Average score:	187.966
# progress:	67.17%
# elapsed time:	37.131 second
# time left:	0.339 hour
# -----------------------------------------------------------
